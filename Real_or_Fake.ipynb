# %% [markdown]
# # Real and AI-Generated Synthetic Images
# ---

# %% [markdown]
# ### 1. รหัส ชื่อ และหมู่ของนิสิตในกลุ่ม
# + 6610450960 นันท์นภัส ภูริภัทรพันธุ์ หมู่ 200
# + 6610450986 พชร พรมแพง หมู่ 200
# + 6610451061 รตนกมล แก้วมาตย์ หมู่ 200

# %% [markdown]
# ### 2. ลิงค์ไปยังข้อมูลที่จะใช้ในระบบต้นแบบ
# https://www.kaggle.com/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images

# %% [markdown]
# ### 3. แหล่งที่มา (คนที่เผยแพร่ได้หรือน่าจะได้ข้อมูลมาอย่างไร เช่น จากคน หรือ sensor)
#
# ##### CIFAKE Dataset:
# + คือ ชุดข้อมูลที่รวบรวมรูปภาพทั้งจาก CIFAR-10 dataset (REAL) และ Stable Diffusion (FAKE) เพื่อให้เป็นข้อมูลที่แบ่งแยกระหว่างภาพที่มนุษย์ถ่ายและภาพที่ AI-Generated ขึ้นมา
# + คลาส: แบ่งเป็น 2 กลุ่มคือ REAL และ FAKE เพื่อใช้ในการศึกษาและพัฒนาโมเดล ในด้านต่าง ๆ
#
# ##### CIFAR-10 Dataset (REAL images):
# + คือ ชุดข้อมูลที่รวบรวมรูปภาพที่มนุษย์ถ่าย (REAL) ถูกสร้างขึ้นโดย Alex Krizhevsky, Vinod Nair, และ Geoffrey Hinton โดยเลือกรูปภาพจาก 80 million tiny images
# + ##### 80 million tiny images #####
#     + คือ ชุดข้อมูลรูปภาพมีขนาด 32x32 พิกเซลและเป็นภาพสี เก็บรวบรวมจากการดาวน์โหลดรูปภาพด้วยการใช้ Web Search ซึ่ง Query คำนามจาก WordNet (Lexical Database หรือ database ที่รวบรวมคลังคำศัพท์) มากกว่า 53,464 คำ และคำนามเหล่านั้นมาเป็น labels ในการแบ่งข้อมูล แต่ในปี 2020 ผู้สร้างได้ประกาศยกเลิกการใช้งานและปิดตัวลง เนื่องจากพบว่ามีรูปภาพในหลาย label จำนวนมากที่มีเนื้อหาไม่เหมาะสม เช่น รูปภาพ racist และ offensive biased และอาจส่งผลให้ model ที่ train มีการ biased เกิดขึ้นตาม
#     + แต่ชุดข้อมูล CIFAR-10 เป็นชุดข้อมูลที่นักวิจัยทั้งสามคน ได้มีการเลือกข้อมูล labels อิสระและไม่มีการ biased เพื่อใช้สำหรับ train model
#
# ##### Stable Diffusion (FAKE images):
# + ใช้ CompVis SD เวอร์ชัน 1.4 ในการสร้างรูปภาพเทียบเท่า (synthetic images) เพื่อให้เหมือนกับรูปภาพจาก CIFAR-10 dataset ถูกสร้างขึ้นโดย Bird & Lotfi (2024) https://ieeexplore.ieee.org/abstract/document/10409290
#
# ดังนั้น CIFAKE dataset เป็นชุดข้อมูลเพื่อคัดเลือกและรวบรวมรูปภาพจากแหล่งต่าง ๆ เพื่อใช้ในการศึกษาและพัฒนาโมเดล โดยมีการแยกแยะระหว่างภาพที่มนุษย์ถ่ายและภาพที่ AI-Generated ขึ้นมา

# %% [markdown]
# ### 4. รูปแบบการจัดเก็บ (เช่น format และ โครงสร้าง)
# Format: JPG files
# CIFAKE datasets มี 2 ชุดข้อมูล คือ REAL และ FAKE
# + โดยโครงสร้างข้างในทั้งคู่มี 10 classes แต่ละ class มีรูป 6000 รูป ทั้งหมด 60000 รูป
# + โดยมีข้อมูลแบบ test 10000 รูป ซึ่งใน 10 class แต่ละ class ถูกสุ่มแบบ Simple Random Sampling จำนวน 1000 รูป
# และแบบ train จำนวน 50000 รูป เป็นการสุ่มรูปภาพแบบ Random order ที่เหลือจาก CIFAR-10
# + โดยข้อมูลแบ่งเป็น 5 training batches และ 1 test batches แต่ละ batch มี 10000 รูป โดย dataset มีทั้งในรูปแบบ Python, Matlab, และ binary โดยข้อมูลเก็บเป็นอาร์เรย์ของ pixel และ labels
#
# โดยข้างใน batch จะเก็บข้อมูลเป็น dictionary โดยมี 2 elements คือ
# 1.  data
# 2. labels
#
# ข้อมูลแบ่งออกเป็น 10 labels name คือ
# 1. airplane
# 2. automobile
# 3. bird
# 4. cat
# 5. deer
# 6. dog
# 7. frog
# 8. horse
# 9. ship
# 10. truck
#
# แสดงให้เห็นว่าข้อมูลของเรา ไม่มี Class Imbalance และทุก labels เท่ากันหมด

# %%
# %pip install pillow

# %%
from IPython.display import display
from PIL import Image

# %%
img = Image.open("test/FAKE/0.jpg")
display(img)
image_format = img.format
image_mode = img.mode
image_size = img.size
print(f"Image Format: {image_format}")
print(f"Image Mode: {image_mode}")
print(f"Image Size: {image_size}")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=32x32>
# Image Format: JPEG
# Image Mode: RGB
# Image Size: (32, 32)

# %%
import os

# Directory containing the files
directory = './train/FAKE'

# Initialize counters for specific labels
counters = {str(i): 0 for i in range(1, 11)}

# Track filenames to check for overlaps
filenames = {str(i): [] for i in range(1, 11)}

# Loop through the files in the directory
for filename in os.listdir(directory):
    if filename.endswith('.jpg'):
        # Check if the file has a label in parentheses
        if '(' in filename and ')' in filename:
            label = filename.split('(')[-1].split(')')[0]
        else:
            label = '1'
        
        # Update the counter if the label is between 1 and 10
        if label in counters:
            counters[label] += 1
            filenames[label].append(filename)

# Print the counts and some sample filenames for each label
for label, count in counters.items():
    print(f'Files ending with ({label}).jpg: {count}')
    print(f'Sample filenames for ({label}): {filenames[label][:5]}')  # Print first 5 filenames for each label
# Out:
# Files ending with (1).jpg: 5000
# Sample filenames for (1): ['1000.jpg', '1001.jpg', '1002.jpg', '1003.jpg', '1004.jpg']
# Files ending with (2).jpg: 5000
# Sample filenames for (2): ['1000 (2).jpg', '1001 (2).jpg', '1002 (2).jpg', '1003 (2).jpg', '1004 (2).jpg']
# Files ending with (3).jpg: 5000
# Sample filenames for (3): ['1000 (3).jpg', '1001 (3).jpg', '1002 (3).jpg', '1003 (3).jpg', '1004 (3).jpg']
# Files ending with (4).jpg: 5000
# Sample filenames for (4): ['1000 (4).jpg', '1001 (4).jpg', '1002 (4).jpg', '1003 (4).jpg', '1004 (4).jpg']
# Files ending with (5).jpg: 5000
# Sample filenames for (5): ['1000 (5).jpg', '1001 (5).jpg', '1002 (5).jpg', '1003 (5).jpg', '1004 (5).jpg']
# Files ending with (6).jpg: 5000
# Sample filenames for (6): ['1000 (6).jpg', '1001 (6).jpg', '1002 (6).jpg', '1003 (6).jpg', '1004 (6).jpg']
# Files ending with (7).jpg: 5000
# Sample filenames for (7): ['1000 (7).jpg', '1001 (7).jpg', '1002 (7).jpg', '1003 (7).jpg', '1004 (7).jpg']
# Files ending with (8).jpg: 5000
# Sample filenames for (8): ['1000 (8).jpg', '1001 (8).jpg', '1002 (8).jpg', '1003 (8).jpg', '1004 (8).jpg']
# Files ending with (9).jpg: 5000
# Sample filenames for (9): ['1000 (9).jpg', '1001 (9).jpg', '1002 (9).jpg', '1003 (9).jpg', '1004 (9).jpg']
# Files ending with (10).jpg: 5000
# Sample filenames for (10): ['1000 (10).jpg', '1001 (10).jpg', '1002 (10).jpg', '1003 (10).jpg', '1004 (10).jpg']

# %%
# %pip install ipyplot

# %%
import ipyplot

# %%
labels = [
    'airplane', 
    'automobile',
    'bird', 
    'cat' ,
    'deer' ,
    'dog',
    'frog', 
    'horse',
    'ship',
    'truck'
]

# %%
train_REAL_images = [
"train/REAL/0000.jpg",
"train/REAL/0000 (2).jpg",
"train/REAL/0000 (3).jpg",
"train/REAL/0000 (4).jpg",
"train/REAL/0000 (5).jpg",
"train/REAL/0000 (6).jpg",
"train/REAL/0000 (7).jpg",
"train/REAL/0000 (8).jpg",
"train/REAL/0000 (9).jpg",
"train/REAL/0000 (10).jpg"
]
ipyplot.plot_class_representations(train_REAL_images, labels, img_width=100)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-mthMH942MNCqzsXUqPS6xh {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-mthMH942MNCqzsXUqPS6xh {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-mthMH942MNCqzsXUqPS6xh {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-mthMH942MNCqzsXUqPS6xh:checked ~ #ipyplot-html-viewer-textarea-mthMH942MNCqzsXUqPS6xh {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-mthMH942MNCqzsXUqPS6xh:checked + #ipyplot-html-viewer-label-mthMH942MNCqzsXUqPS6xh:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-mthMH942MNCqzsXUqPS6xh">
#         <label id="ipyplot-html-viewer-label-mthMH942MNCqzsXUqPS6xh" for="ipyplot-html-viewer-toggle-mthMH942MNCqzsXUqPS6xh">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-mthMH942MNCqzsXUqPS6xh" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-fx9HbNq8VS4Z6UEJF4Xvam {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-fx9HbNq8VS4Z6UEJF4Xvam {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-fx9HbNq8VS4Z6UEJF4Xvam">
#     <div class="ipyplot-placeholder-div-fx9HbNq8VS4Z6UEJF4Xvam">
#         <div id="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-5ih3FmwCkZYHrpV7RY9sgZ" class="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam">
#             <h4 style="font-size: 12px; word-wrap: break-word;">airplane</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\REAL\0000.jpg</h4><img src="train\REAL\0000.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-5ih3FmwCkZYHrpV7RY9sgZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fx9HbNq8VS4Z6UEJF4Xvam">
#         <div id="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-HGmtdAkXR9jr7CN9myTrME" class="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam">
#             <h4 style="font-size: 12px; word-wrap: break-word;">automobile</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\REAL\0000 (2).jpg</h4><img src="train\REAL\0000 (2).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-HGmtdAkXR9jr7CN9myTrME">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fx9HbNq8VS4Z6UEJF4Xvam">
#         <div id="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-dAHoVdYrbruGuJwLKKKctr" class="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bird</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\REAL\0000 (3).jpg</h4><img src="train\REAL\0000 (3).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-dAHoVdYrbruGuJwLKKKctr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fx9HbNq8VS4Z6UEJF4Xvam">
#         <div id="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-8oTqUnZSfrRazLbZs8gNAv" class="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cat</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\REAL\0000 (4).jpg</h4><img src="train\REAL\0000 (4).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-8oTqUnZSfrRazLbZs8gNAv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fx9HbNq8VS4Z6UEJF4Xvam">
#         <div id="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-bnREDfkQ6SZsg9i82Rtc44" class="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam">
#             <h4 style="font-size: 12px; word-wrap: break-word;">deer</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\REAL\0000 (5).jpg</h4><img src="train\REAL\0000 (5).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-bnREDfkQ6SZsg9i82Rtc44">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fx9HbNq8VS4Z6UEJF4Xvam">
#         <div id="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-WJQuiZhJBqhBMuqFULbsaC" class="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam">
#             <h4 style="font-size: 12px; word-wrap: break-word;">dog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\REAL\0000 (6).jpg</h4><img src="train\REAL\0000 (6).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a h
#         <style>
#         #ipyplot-imgs-container-div-fx9HbNq8VS4Z6UEJF4Xvam {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-fx9HbNq8VS4Z6UEJF4Xvam {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-fx9HbNq8VS4Z6UEJF4Xvam">
#     <div class="ipyplot-placeholder-div-fx9HbNq8VS4Z6UEJF4Xvam">
#         <div id="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-5ih3FmwCkZYHrpV7RY9sgZ" class="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam">
#             <h4 style="font-size: 12px; word-wrap: break-word;">airplane</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\REAL\0000.jpg</h4><img src="train\REAL\0000.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-5ih3FmwCkZYHrpV7RY9sgZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fx9HbNq8VS4Z6UEJF4Xvam">
#         <div id="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-HGmtdAkXR9jr7CN9myTrME" class="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam">
#             <h4 style="font-size: 12px; word-wrap: break-word;">automobile</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\REAL\0000 (2).jpg</h4><img src="train\REAL\0000 (2).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-HGmtdAkXR9jr7CN9myTrME">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fx9HbNq8VS4Z6UEJF4Xvam">
#         <div id="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-dAHoVdYrbruGuJwLKKKctr" class="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bird</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\REAL\0000 (3).jpg</h4><img src="train\REAL\0000 (3).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-dAHoVdYrbruGuJwLKKKctr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fx9HbNq8VS4Z6UEJF4Xvam">
#         <div id="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-8oTqUnZSfrRazLbZs8gNAv" class="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cat</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\REAL\0000 (4).jpg</h4><img src="train\REAL\0000 (4).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-8oTqUnZSfrRazLbZs8gNAv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fx9HbNq8VS4Z6UEJF4Xvam">
#         <div id="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-bnREDfkQ6SZsg9i82Rtc44" class="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam">
#             <h4 style="font-size: 12px; word-wrap: break-word;">deer</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\REAL\0000 (5).jpg</h4><img src="train\REAL\0000 (5).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-bnREDfkQ6SZsg9i82Rtc44">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fx9HbNq8VS4Z6UEJF4Xvam">
#         <div id="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-WJQuiZhJBqhBMuqFULbsaC" class="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam">
#             <h4 style="font-size: 12px; word-wrap: break-word;">dog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\REAL\0000 (6).jpg</h4><img src="train\REAL\0000 (6).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-WJQuiZhJBqhBMuqFULbsaC">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fx9HbNq8VS4Z6UEJF4Xvam">
#         <div id="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-PFNYGrTZ9mmoiYGHzjQ8Bf" class="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam">
#             <h4 style="font-size: 12px; word-wrap: break-word;">frog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\REAL\0000 (7).jpg</h4><img src="train\REAL\0000 (7).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-PFNYGrTZ9mmoiYGHzjQ8Bf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fx9HbNq8VS4Z6UEJF4Xvam">
#         <div id="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-oUT5yAbpWbEfn9gc6YWku7" class="ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam">
#             <h4 style="font-size: 12px; word-wrap: break-word;">horse</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\REAL\0000 (8).jpg</h4><img src="train\REAL\0000 (8).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fx9HbNq8VS4Z6UEJF4Xvam-oUT5yAb

# %%
train_FAKE_images = [
"train/FAKE/1000.jpg",
"train/FAKE/1000 (2).jpg",
"train/FAKE/1000 (3).jpg",
"train/FAKE/1000 (4).jpg",
"train/FAKE/1000 (5).jpg",
"train/FAKE/1000 (6).jpg",
"train/FAKE/1000 (7).jpg",
"train/FAKE/1000 (8).jpg",
"train/FAKE/1000 (9).jpg",
"train/FAKE/1000 (10).jpg"
]
ipyplot.plot_class_representations(train_FAKE_images, labels, img_width=100)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-aL9ggX3iMAazqMKJpxg9ne {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-aL9ggX3iMAazqMKJpxg9ne {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-aL9ggX3iMAazqMKJpxg9ne {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-aL9ggX3iMAazqMKJpxg9ne:checked ~ #ipyplot-html-viewer-textarea-aL9ggX3iMAazqMKJpxg9ne {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-aL9ggX3iMAazqMKJpxg9ne:checked + #ipyplot-html-viewer-label-aL9ggX3iMAazqMKJpxg9ne:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-aL9ggX3iMAazqMKJpxg9ne">
#         <label id="ipyplot-html-viewer-label-aL9ggX3iMAazqMKJpxg9ne" for="ipyplot-html-viewer-toggle-aL9ggX3iMAazqMKJpxg9ne">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-aL9ggX3iMAazqMKJpxg9ne" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-YvyJ9RVvyLz7nuYV8KjLhB {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-YvyJ9RVvyLz7nuYV8KjLhB {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-YvyJ9RVvyLz7nuYV8KjLhB">
#     <div class="ipyplot-placeholder-div-YvyJ9RVvyLz7nuYV8KjLhB">
#         <div id="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-nJmAHFBbxZNCB2DybG6NjB" class="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">airplane</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\FAKE\1000.jpg</h4><img src="train\FAKE\1000.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-nJmAHFBbxZNCB2DybG6NjB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-YvyJ9RVvyLz7nuYV8KjLhB">
#         <div id="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-8sS7jhnMpNxfxdBSsaPeMA" class="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">automobile</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\FAKE\1000 (2).jpg</h4><img src="train\FAKE\1000 (2).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-8sS7jhnMpNxfxdBSsaPeMA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-YvyJ9RVvyLz7nuYV8KjLhB">
#         <div id="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-WxF49ohvPmCu84f42r9Ucv" class="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bird</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\FAKE\1000 (3).jpg</h4><img src="train\FAKE\1000 (3).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-WxF49ohvPmCu84f42r9Ucv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-YvyJ9RVvyLz7nuYV8KjLhB">
#         <div id="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-bMskQKHSXQq4YijJwAnSMf" class="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cat</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\FAKE\1000 (4).jpg</h4><img src="train\FAKE\1000 (4).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-bMskQKHSXQq4YijJwAnSMf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-YvyJ9RVvyLz7nuYV8KjLhB">
#         <div id="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-bkFJ4yHoieXQc7br29sSub" class="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">deer</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\FAKE\1000 (5).jpg</h4><img src="train\FAKE\1000 (5).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-bkFJ4yHoieXQc7br29sSub">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-YvyJ9RVvyLz7nuYV8KjLhB">
#         <div id="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-DiU9jzBPwT8LLML2i6xPU9" class="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">dog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\FAKE\1000 (6).jpg</h4><img src="train\FAKE\1000 (6).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a h
#         <style>
#         #ipyplot-imgs-container-div-YvyJ9RVvyLz7nuYV8KjLhB {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-YvyJ9RVvyLz7nuYV8KjLhB {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-YvyJ9RVvyLz7nuYV8KjLhB">
#     <div class="ipyplot-placeholder-div-YvyJ9RVvyLz7nuYV8KjLhB">
#         <div id="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-nJmAHFBbxZNCB2DybG6NjB" class="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">airplane</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\FAKE\1000.jpg</h4><img src="train\FAKE\1000.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-nJmAHFBbxZNCB2DybG6NjB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-YvyJ9RVvyLz7nuYV8KjLhB">
#         <div id="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-8sS7jhnMpNxfxdBSsaPeMA" class="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">automobile</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\FAKE\1000 (2).jpg</h4><img src="train\FAKE\1000 (2).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-8sS7jhnMpNxfxdBSsaPeMA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-YvyJ9RVvyLz7nuYV8KjLhB">
#         <div id="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-WxF49ohvPmCu84f42r9Ucv" class="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bird</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\FAKE\1000 (3).jpg</h4><img src="train\FAKE\1000 (3).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-WxF49ohvPmCu84f42r9Ucv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-YvyJ9RVvyLz7nuYV8KjLhB">
#         <div id="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-bMskQKHSXQq4YijJwAnSMf" class="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cat</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\FAKE\1000 (4).jpg</h4><img src="train\FAKE\1000 (4).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-bMskQKHSXQq4YijJwAnSMf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-YvyJ9RVvyLz7nuYV8KjLhB">
#         <div id="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-bkFJ4yHoieXQc7br29sSub" class="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">deer</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\FAKE\1000 (5).jpg</h4><img src="train\FAKE\1000 (5).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-bkFJ4yHoieXQc7br29sSub">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-YvyJ9RVvyLz7nuYV8KjLhB">
#         <div id="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-DiU9jzBPwT8LLML2i6xPU9" class="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">dog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\FAKE\1000 (6).jpg</h4><img src="train\FAKE\1000 (6).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-DiU9jzBPwT8LLML2i6xPU9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-YvyJ9RVvyLz7nuYV8KjLhB">
#         <div id="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-BtRgnhikttPcYSQCawLJbg" class="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">frog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\FAKE\1000 (7).jpg</h4><img src="train\FAKE\1000 (7).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-BtRgnhikttPcYSQCawLJbg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-YvyJ9RVvyLz7nuYV8KjLhB">
#         <div id="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-TPUwuGWsEa7BLNDyaXd3Hn" class="ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB">
#             <h4 style="font-size: 12px; word-wrap: break-word;">horse</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">train\FAKE\1000 (8).jpg</h4><img src="train\FAKE\1000 (8).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-YvyJ9RVvyLz7nuYV8KjLhB-TPUwuGW

# %%
test_REAL_images = [
"test/REAL/0000.jpg",
"test/REAL/0000 (2).jpg",
"test/REAL/0000 (3).jpg",
"test/REAL/0000 (4).jpg",
"test/REAL/0000 (5).jpg",
"test/REAL/0000 (6).jpg",
"test/REAL/0000 (7).jpg",
"test/REAL/0000 (8).jpg",
"test/REAL/0000 (9).jpg",
"test/REAL/0000 (10).jpg"
]
ipyplot.plot_class_representations(test_REAL_images, labels, img_width=100)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-oEy3pdwp3pPwoGaVe75U4y {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-oEy3pdwp3pPwoGaVe75U4y {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-oEy3pdwp3pPwoGaVe75U4y {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-oEy3pdwp3pPwoGaVe75U4y:checked ~ #ipyplot-html-viewer-textarea-oEy3pdwp3pPwoGaVe75U4y {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-oEy3pdwp3pPwoGaVe75U4y:checked + #ipyplot-html-viewer-label-oEy3pdwp3pPwoGaVe75U4y:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-oEy3pdwp3pPwoGaVe75U4y">
#         <label id="ipyplot-html-viewer-label-oEy3pdwp3pPwoGaVe75U4y" for="ipyplot-html-viewer-toggle-oEy3pdwp3pPwoGaVe75U4y">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-oEy3pdwp3pPwoGaVe75U4y" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-iw2JNznMP2irUMegTHtXro {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-iw2JNznMP2irUMegTHtXro {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-iw2JNznMP2irUMegTHtXro {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-iw2JNznMP2irUMegTHtXro span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-iw2JNznMP2irUMegTHtXro span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-iw2JNznMP2irUMegTHtXro img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-iw2JNznMP2irUMegTHtXro span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-iw2JNznMP2irUMegTHtXro span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-iw2JNznMP2irUMegTHtXro]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-iw2JNznMP2irUMegTHtXro]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-iw2JNznMP2irUMegTHtXro]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-iw2JNznMP2irUMegTHtXro">
#     <div class="ipyplot-placeholder-div-iw2JNznMP2irUMegTHtXro">
#         <div id="ipyplot-content-div-iw2JNznMP2irUMegTHtXro-krTGE95q9eUg5n7i66cz2P" class="ipyplot-content-div-iw2JNznMP2irUMegTHtXro">
#             <h4 style="font-size: 12px; word-wrap: break-word;">airplane</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\REAL\0000.jpg</h4><img src="test\REAL\0000.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iw2JNznMP2irUMegTHtXro-krTGE95q9eUg5n7i66cz2P">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iw2JNznMP2irUMegTHtXro">
#         <div id="ipyplot-content-div-iw2JNznMP2irUMegTHtXro-ADw7yubPz9nSEYi6Pj4ogj" class="ipyplot-content-div-iw2JNznMP2irUMegTHtXro">
#             <h4 style="font-size: 12px; word-wrap: break-word;">automobile</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\REAL\0000 (2).jpg</h4><img src="test\REAL\0000 (2).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iw2JNznMP2irUMegTHtXro-ADw7yubPz9nSEYi6Pj4ogj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iw2JNznMP2irUMegTHtXro">
#         <div id="ipyplot-content-div-iw2JNznMP2irUMegTHtXro-2tZrJUDU58weMmFCoKEser" class="ipyplot-content-div-iw2JNznMP2irUMegTHtXro">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bird</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\REAL\0000 (3).jpg</h4><img src="test\REAL\0000 (3).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iw2JNznMP2irUMegTHtXro-2tZrJUDU58weMmFCoKEser">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iw2JNznMP2irUMegTHtXro">
#         <div id="ipyplot-content-div-iw2JNznMP2irUMegTHtXro-UA42PgSyBZTPZ3WHYFZUvT" class="ipyplot-content-div-iw2JNznMP2irUMegTHtXro">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cat</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\REAL\0000 (4).jpg</h4><img src="test\REAL\0000 (4).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iw2JNznMP2irUMegTHtXro-UA42PgSyBZTPZ3WHYFZUvT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iw2JNznMP2irUMegTHtXro">
#         <div id="ipyplot-content-div-iw2JNznMP2irUMegTHtXro-Mcxx2Zthxt442VDo4MNBBJ" class="ipyplot-content-div-iw2JNznMP2irUMegTHtXro">
#             <h4 style="font-size: 12px; word-wrap: break-word;">deer</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\REAL\0000 (5).jpg</h4><img src="test\REAL\0000 (5).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iw2JNznMP2irUMegTHtXro-Mcxx2Zthxt442VDo4MNBBJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iw2JNznMP2irUMegTHtXro">
#         <div id="ipyplot-content-div-iw2JNznMP2irUMegTHtXro-gGAt9CrZBeYzhAzK4RcRqz" class="ipyplot-content-div-iw2JNznMP2irUMegTHtXro">
#             <h4 style="font-size: 12px; word-wrap: break-word;">dog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\REAL\0000 (6).jpg</h4><img src="test\REAL\0000 (6).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplo
#         <style>
#         #ipyplot-imgs-container-div-iw2JNznMP2irUMegTHtXro {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-iw2JNznMP2irUMegTHtXro {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-iw2JNznMP2irUMegTHtXro {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-iw2JNznMP2irUMegTHtXro span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-iw2JNznMP2irUMegTHtXro span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-iw2JNznMP2irUMegTHtXro img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-iw2JNznMP2irUMegTHtXro span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-iw2JNznMP2irUMegTHtXro span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-iw2JNznMP2irUMegTHtXro]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-iw2JNznMP2irUMegTHtXro]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-iw2JNznMP2irUMegTHtXro]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-iw2JNznMP2irUMegTHtXro">
#     <div class="ipyplot-placeholder-div-iw2JNznMP2irUMegTHtXro">
#         <div id="ipyplot-content-div-iw2JNznMP2irUMegTHtXro-krTGE95q9eUg5n7i66cz2P" class="ipyplot-content-div-iw2JNznMP2irUMegTHtXro">
#             <h4 style="font-size: 12px; word-wrap: break-word;">airplane</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\REAL\0000.jpg</h4><img src="test\REAL\0000.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iw2JNznMP2irUMegTHtXro-krTGE95q9eUg5n7i66cz2P">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iw2JNznMP2irUMegTHtXro">
#         <div id="ipyplot-content-div-iw2JNznMP2irUMegTHtXro-ADw7yubPz9nSEYi6Pj4ogj" class="ipyplot-content-div-iw2JNznMP2irUMegTHtXro">
#             <h4 style="font-size: 12px; word-wrap: break-word;">automobile</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\REAL\0000 (2).jpg</h4><img src="test\REAL\0000 (2).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iw2JNznMP2irUMegTHtXro-ADw7yubPz9nSEYi6Pj4ogj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iw2JNznMP2irUMegTHtXro">
#         <div id="ipyplot-content-div-iw2JNznMP2irUMegTHtXro-2tZrJUDU58weMmFCoKEser" class="ipyplot-content-div-iw2JNznMP2irUMegTHtXro">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bird</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\REAL\0000 (3).jpg</h4><img src="test\REAL\0000 (3).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iw2JNznMP2irUMegTHtXro-2tZrJUDU58weMmFCoKEser">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iw2JNznMP2irUMegTHtXro">
#         <div id="ipyplot-content-div-iw2JNznMP2irUMegTHtXro-UA42PgSyBZTPZ3WHYFZUvT" class="ipyplot-content-div-iw2JNznMP2irUMegTHtXro">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cat</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\REAL\0000 (4).jpg</h4><img src="test\REAL\0000 (4).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iw2JNznMP2irUMegTHtXro-UA42PgSyBZTPZ3WHYFZUvT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iw2JNznMP2irUMegTHtXro">
#         <div id="ipyplot-content-div-iw2JNznMP2irUMegTHtXro-Mcxx2Zthxt442VDo4MNBBJ" class="ipyplot-content-div-iw2JNznMP2irUMegTHtXro">
#             <h4 style="font-size: 12px; word-wrap: break-word;">deer</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\REAL\0000 (5).jpg</h4><img src="test\REAL\0000 (5).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iw2JNznMP2irUMegTHtXro-Mcxx2Zthxt442VDo4MNBBJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iw2JNznMP2irUMegTHtXro">
#         <div id="ipyplot-content-div-iw2JNznMP2irUMegTHtXro-gGAt9CrZBeYzhAzK4RcRqz" class="ipyplot-content-div-iw2JNznMP2irUMegTHtXro">
#             <h4 style="font-size: 12px; word-wrap: break-word;">dog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\REAL\0000 (6).jpg</h4><img src="test\REAL\0000 (6).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iw2JNznMP2irUMegTHtXro-gGAt9CrZBeYzhAzK4RcRqz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iw2JNznMP2irUMegTHtXro">
#         <div id="ipyplot-content-div-iw2JNznMP2irUMegTHtXro-5Pz55Gzq33X3dgb6GYDBUz" class="ipyplot-content-div-iw2JNznMP2irUMegTHtXro">
#             <h4 style="font-size: 12px; word-wrap: break-word;">frog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\REAL\0000 (7).jpg</h4><img src="test\REAL\0000 (7).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iw2JNznMP2irUMegTHtXro-5Pz55Gzq33X3dgb6GYDBUz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-iw2JNznMP2irUMegTHtXro">
#         <div id="ipyplot-content-div-iw2JNznMP2irUMegTHtXro-EmSDaAxufSvxSzuigm4gvD" class="ipyplot-content-div-iw2JNznMP2irUMegTHtXro">
#             <h4 style="font-size: 12px; word-wrap: break-word;">horse</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\REAL\0000 (8).jpg</h4><img src="test\REAL\0000 (8).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-iw2JNznMP2irUMegTHtXro-EmSDaAxufSvxSzuigm4gvD"

# %%
test_FAKE_images = [
"test/FAKE/0.jpg",
"test/FAKE/0 (2).jpg",
"test/FAKE/0 (3).jpg",
"test/FAKE/0 (4).jpg",
"test/FAKE/0 (5).jpg",
"test/FAKE/0 (6).jpg",
"test/FAKE/0 (7).jpg",
"test/FAKE/0 (8).jpg",
"test/FAKE/0 (9).jpg",
"test/FAKE/0 (10).jpg"
]
ipyplot.plot_class_representations(test_FAKE_images, labels, img_width=100)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-DVq6ZbBa7KxFtpmvSSB7qm {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-DVq6ZbBa7KxFtpmvSSB7qm {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-DVq6ZbBa7KxFtpmvSSB7qm {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-DVq6ZbBa7KxFtpmvSSB7qm:checked ~ #ipyplot-html-viewer-textarea-DVq6ZbBa7KxFtpmvSSB7qm {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-DVq6ZbBa7KxFtpmvSSB7qm:checked + #ipyplot-html-viewer-label-DVq6ZbBa7KxFtpmvSSB7qm:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-DVq6ZbBa7KxFtpmvSSB7qm">
#         <label id="ipyplot-html-viewer-label-DVq6ZbBa7KxFtpmvSSB7qm" for="ipyplot-html-viewer-toggle-DVq6ZbBa7KxFtpmvSSB7qm">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-DVq6ZbBa7KxFtpmvSSB7qm" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-PorjCm3X8Gv9rLvSX76NpQ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-PorjCm3X8Gv9rLvSX76NpQ {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-PorjCm3X8Gv9rLvSX76NpQ">
#     <div class="ipyplot-placeholder-div-PorjCm3X8Gv9rLvSX76NpQ">
#         <div id="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-L6nPbXzHtCjqK4mZWJQJVU" class="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">airplane</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\FAKE\0.jpg</h4><img src="test\FAKE\0.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-L6nPbXzHtCjqK4mZWJQJVU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PorjCm3X8Gv9rLvSX76NpQ">
#         <div id="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-jo26XdRWDw3DayERvJtGYe" class="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">automobile</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\FAKE\0 (2).jpg</h4><img src="test\FAKE\0 (2).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-jo26XdRWDw3DayERvJtGYe">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PorjCm3X8Gv9rLvSX76NpQ">
#         <div id="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-BqmGAZXXZxeBCvKJRicf5y" class="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bird</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\FAKE\0 (3).jpg</h4><img src="test\FAKE\0 (3).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-BqmGAZXXZxeBCvKJRicf5y">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PorjCm3X8Gv9rLvSX76NpQ">
#         <div id="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-J4eB4zYTVU3ExwtFSE88qN" class="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cat</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\FAKE\0 (4).jpg</h4><img src="test\FAKE\0 (4).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-J4eB4zYTVU3ExwtFSE88qN">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PorjCm3X8Gv9rLvSX76NpQ">
#         <div id="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-fu2dHby9eDaXwRATGf3HQp" class="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">deer</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\FAKE\0 (5).jpg</h4><img src="test\FAKE\0 (5).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-fu2dHby9eDaXwRATGf3HQp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PorjCm3X8Gv9rLvSX76NpQ">
#         <div id="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-ZKyazQC5kjB6vTHvjbNb9d" class="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">dog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\FAKE\0 (6).jpg</h4><img src="test\FAKE\0 (6).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ
#         <style>
#         #ipyplot-imgs-container-div-PorjCm3X8Gv9rLvSX76NpQ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-PorjCm3X8Gv9rLvSX76NpQ {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-PorjCm3X8Gv9rLvSX76NpQ">
#     <div class="ipyplot-placeholder-div-PorjCm3X8Gv9rLvSX76NpQ">
#         <div id="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-L6nPbXzHtCjqK4mZWJQJVU" class="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">airplane</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\FAKE\0.jpg</h4><img src="test\FAKE\0.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-L6nPbXzHtCjqK4mZWJQJVU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PorjCm3X8Gv9rLvSX76NpQ">
#         <div id="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-jo26XdRWDw3DayERvJtGYe" class="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">automobile</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\FAKE\0 (2).jpg</h4><img src="test\FAKE\0 (2).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-jo26XdRWDw3DayERvJtGYe">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PorjCm3X8Gv9rLvSX76NpQ">
#         <div id="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-BqmGAZXXZxeBCvKJRicf5y" class="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bird</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\FAKE\0 (3).jpg</h4><img src="test\FAKE\0 (3).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-BqmGAZXXZxeBCvKJRicf5y">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PorjCm3X8Gv9rLvSX76NpQ">
#         <div id="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-J4eB4zYTVU3ExwtFSE88qN" class="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cat</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\FAKE\0 (4).jpg</h4><img src="test\FAKE\0 (4).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-J4eB4zYTVU3ExwtFSE88qN">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PorjCm3X8Gv9rLvSX76NpQ">
#         <div id="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-fu2dHby9eDaXwRATGf3HQp" class="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">deer</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\FAKE\0 (5).jpg</h4><img src="test\FAKE\0 (5).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-fu2dHby9eDaXwRATGf3HQp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PorjCm3X8Gv9rLvSX76NpQ">
#         <div id="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-ZKyazQC5kjB6vTHvjbNb9d" class="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">dog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\FAKE\0 (6).jpg</h4><img src="test\FAKE\0 (6).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-ZKyazQC5kjB6vTHvjbNb9d">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PorjCm3X8Gv9rLvSX76NpQ">
#         <div id="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-8CtJiKnUBdcJbhEStZA3m2" class="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">frog</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\FAKE\0 (7).jpg</h4><img src="test\FAKE\0 (7).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-8CtJiKnUBdcJbhEStZA3m2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-PorjCm3X8Gv9rLvSX76NpQ">
#         <div id="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-8TF6StBQunakWGDNuSA3cp" class="ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">horse</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">test\FAKE\0 (8).jpg</h4><img src="test\FAKE\0 (8).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-PorjCm3X8Gv9rLvSX76NpQ-8TF6StBQunakWGDNuSA3cp">
#                 <span class="ipyplot-img-expan

# %% [markdown]
# ### 5.  จำนวนข้อมูล ("ตัวอย่าง"/"sample"/"example"/"instance"/"data point") ในชุดข้อมูล
#
# + Training images: 100000 images (FAKE 50000, REAL 50000)
#
# + Test images: 20000 images (FAKE 10000, REAL 10000)

# %%
import os

train = os.listdir("D:\Mook\\262_ML\HW\\train") 
print("\\train contains {len_folder} file(s).".format(len_folder=len(train)))

train_REAL = os.listdir("D:\Mook\\262_ML\HW\\train\REAL") 
print("  \\train\REAL contains {len_folder} file(s).".format(len_folder=len(train_REAL)))

train_FAKE = os.listdir("D:\Mook\\262_ML\HW\\train\FAKE") 
print("  \\train\FAKE contains {len_folder} file(s).".format(len_folder=len(train_FAKE)))

test = os.listdir("D:\Mook\\262_ML\HW\\test") 
print("\\test contains {len_folder} file(s).".format(len_folder=len(test)))

test_FAKE = os.listdir("D:\Mook\\262_ML\HW\\test\FAKE")
print("  \\test\FAKE contains {len_folder} file(s).".format(len_folder=len(test_FAKE)))

test_REAL = os.listdir("D:\Mook\\262_ML\HW\\test\REAL") 
print("  \\test\REAL contains {len_folder} file(s).".format(len_folder=len(test_REAL)))
# Out:
# \train contains 2 file(s).
#   \train\REAL contains 50000 file(s).
#   \train\FAKE contains 50000 file(s).
# \test contains 2 file(s).
#   \test\FAKE contains 10000 file(s).
#   \test\REAL contains 10000 file(s).

# %% [markdown]
# ### 6. สิ่งที่ต้องการทำนาย ("คำตอบ"/"เฉลย"/"class"/"label"/"target") คืออะไร
# Binary Classification ว่าเป็นรูปภาพ AI-generated หรือ ภาพจากมนุษย์

# %% [markdown]
# ### 7. สิ่งที่ใช้ในการทำนาย ("คุณลักษณะ"/"feature") คืออะไร (เช่น ค่าอะไรบ้าง ข้อความอะไร รูปภาพอะไร หรืออื่น ๆ)
# + รูปภาพที่ AI-generated
# + รูปภาพจริงที่ถูกถ่ายมนุษย์

# %% [markdown]
# ### 8. ต้องมีการเตรียม/ประมวลผลข้อมูลส่วนไหนก่อนหรือไม่ เพราะอะไร อย่างไร
# + ต้องมีการทำ image processing เนื่องจาก ข้อมูลที่นำเข้าและข้อมูลที่ใช้ประมวลผลเป็น image
# + Transfer Learning นำโมเดลของคนอื่นมาปรับใช้กับข้อมูลตัวอย่างของเรา เพื่อลดเวลาในการพัฒนาโมเดลของเราและมีประสิทธิภาพเพิ่มมากขึ้น และสามารถตรวจสอบความแม่นยำของ Algorithm ที่เราใช้ในโมเดลแรก และสามารถปรับ Algorithm ให้ดีขึ้นได้ในโมเดลตัวถัดไป

# %% [markdown]
# ### 9. มีข้อมูลที่ไม่น่าจะได้ใช้ในระบบต้นแบบของเราอยู่ด้วยหรือไม่ เพราะอะไร
# ไม่มี เนื่องจากระบบต้นแบบต้องใช้ข้อมูลเป็นรูปภาพในการประมวลผลข้อมูล และข้อมูลใน datasets สามารถใช้ข้อมูลได้ทั้งหมด

# %% [markdown]
# ### 10. ข้อมูลควรถูกนำไปจัดเก็บในรูปแบบอื่นหรือไม่ เพราะอะไร อย่างไร
# ไม่มี เนื่องจากข้อมูลไม่จำเป็นต้องจัดเก็บในรูปแบบข้อมูลที่ซับซ้อน

# %% [markdown]
# ### 11. ประเด็นอื่น ๆ ที่เกี่ยวข้องกับข้อมูลของตัวเอง
# datasets ที่ใช้เป็นรูปภาพประเภทรูปถ่าย โดยไม่มีข้อมูลประเภทรูปวาด

# %% [markdown]
# ### 12. การมีส่วนร่วมของสมาชิกแต่ละคนในกลุ่ม
# + 6610450960 นันท์นภัส ภูริภัทรพันธุ์ (เลือก datasets, เรียบเรียงข้อมูล)
# + 6610450986 พชร พรมแพง (เลือก datasets, สรุปและวิเคราะห์ข้อมูล)
# + 6610451061 รตนกมล แก้วมาตย์ (เลือก datasets, สรุปและวิเคราะห์ข้อมูล)

# %% [markdown]
# ### 13. การเปิดเผยการใช้เครื่องมือปัญญาประดิษฐ์
# + ChatGPT
# + Gemini
# <!-- ? . ระบุว่าใชข้ AI ทำอะไรบ้าง โดยละเอียด ไม่ควรใช้ AI ในการตรวจสอบข้อมูล -->
